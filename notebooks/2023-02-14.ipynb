# %%
import matplotlib.pyplot as plt
import scipy.stats

xs = scipy.stats.norm.rvs(5, 2, 10000)

fig, ax = plt.subplots(1, 2, figsize=(9, 3))
ax[0].hist(xs, bins=50)
ax[0].set_title("Samples")
ax[1].hist(
    scipy.stats.norm.cdf(xs, 5, 2),
    bins=50,
)
ax[1].set_title("CDF(samples)")
# Out:
# Text(0.5, 1.0, 'CDF(samples)')
